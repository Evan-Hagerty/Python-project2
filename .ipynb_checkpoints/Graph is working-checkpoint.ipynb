# %%
# Require imports to run code
import pandas_datareader as web
from datetime import datetime
import pandas as pd 
import plotly.express as px

# %%
# Start and end dates for comparison and charting. 
start = datetime(2000,1,1)
end = datetime(2020,1,1)
# Control of S&P 500 and variables of stocks to compare.
stock = '^GSPC'
comp_stock= []
stock_pick= []

# %%
# Stocks from the S&P 500 to compare against the full S&P 500 
stock_pick = ["MMM", "AOS", "ABT",]
# Code to reference CSV file 
ticker = pd.read_csv(r'C:\Users\evanh\python-project2\sp500.csv')
# For loop to make sure comparing stocks are part of the S&P 500
for i in stock_pick:
    if i in ticker["Symbol"].values:
        comp_stock.append(stock_pick)
    else:
        print("One these tickers was not found.")
print(comp_stock[1]) # Print to show which company from the list should be graphed below
# Out:
# ['MMM', 'AOS', 'ABT']

# %%
# Reading data from yahoo finance to complete chart and show values for S&P 500
df = web.DataReader(stock,'yahoo',start,end)
df = df.reset_index()
print(df.head())
# Out:
#         Date         High          Low         Open        Close      Volume  \
# 0 2000-01-03  1478.000000  1438.359985  1469.250000  1455.219971   931800000
# 1 2000-01-04  1455.219971  1397.430054  1455.219971  1399.420044  1009000000
# 2 2000-01-05  1413.270020  1377.680054  1399.420044  1402.109985  1085500000
# 3 2000-01-06  1411.900024  1392.099976  1402.109985  1403.449951  1092300000
# 4 2000-01-07  1441.469971  1400.729980  1403.449951  1441.469971  1225200000
#
#      Adj Close
# 0  1455.219971
# 1  1399.420044
# 2  1402.109985
# 3  1403.449951
# 4  1441.469971

# %%
# Reading data from yahoo finance to complete chart of selected stock to compare against the S&P 500
cs = web.DataReader(stock_pick[1],'yahoo',start,end)
cs = cs.reset_index()
print(cs.head())
# Out:
#         Date      High       Low      Open     Close    Volume  Adj Close
# 0 2000-01-03  3.645833  3.572917  3.635417  3.614583  113200.0   2.445834
# 1 2000-01-04  3.666667  3.562500  3.604167  3.562500  164400.0   2.410592
# 2 2000-01-05  3.583333  3.489583  3.583333  3.552083  188400.0   2.403544
# 3 2000-01-06  3.552083  3.500000  3.541667  3.500000  161200.0   2.368301
# 4 2000-01-07  3.645833  3.520833  3.520833  3.645833  106000.0   2.466980

# %%
# Using plotly to complete graphs and populate graph with "Adj closing" values
fig = px.line(df, x="Date", y="Adj Close", title='20 Year S&P 500')
fig2 = px.line(cs, x="Date", y="Adj Close", title='20 Years against S&P 500')
fig2.update_layout(title="20 years of " + stock_pick[1])
fig.show()
fig2.show()
# Out:
# <div>                            <div id="8d78b199-dc2f-49d2-bf62-f0fd76239407" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d78b199-dc2f-49d2-bf62-f0fd76239407")) {                    Plotly.newPlot(                        "8d78b199-dc2f-49d2-bf62-f0fd76239407",                        [{"hovertemplate": "Date=%{x}<br>Adj Close=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2000-01-03T00:00:00", "2000-01-04T00:00:00", "2000-01-05T00:00:00", "2000-01-06T00:00:00", "2000-01-07T00:00:00", "2000-01-10T00:00:00", "2000-01-11T00:00:00", "2000-01-12T00:00:00", "2000-01-13T00:00:00", "2000-01-14T00:00:00", "2000-01-18T00:00:00", "2000-0
# ...
